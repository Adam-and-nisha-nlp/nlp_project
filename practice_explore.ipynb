# %%
# standarad imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import unicodedata

# import regular expression operations
import re

# import natural language toolkit
import nltk
# import stopwords list
from nltk.corpus import stopwords
# import wordcloud
from wordcloud import WordCloud

import requests
from bs4 import BeautifulSoup
import os
from pprint import pprint 
import time
import json

import acquire as a
import wrangle as w

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_json('data.json')
data
# Out:
#            id                           node_id  \
# 0   160983886  MDEwOlJlcG9zaXRvcnkxNjA5ODM4ODY=
# 1   100740147  MDEwOlJlcG9zaXRvcnkxMDA3NDAxNDc=
# 2   116997617  MDEwOlJlcG9zaXRvcnkxMTY5OTc2MTc=
# 3    76322499  MDEwOlJlcG9zaXRvcnk3NjMyMjQ5OQ==
# 4   205845429  MDEwOlJlcG9zaXRvcnkyMDU4NDU0Mjk=
# ..        ...                               ...
# 95  600644327                      R_kgDOI80a5w
# 96  231036405  MDEwOlJlcG9zaXRvcnkyMzEwMzY0MDU=
# 97  181954863  MDEwOlJlcG9zaXRvcnkxODE5NTQ4NjM=
# 98  122978492  MDEwOlJlcG9zaXRvcnkxMjI5Nzg0OTI=
# 99  286827980  MDEwOlJlcG9zaXRvcnkyODY4Mjc5ODA=
#
#                                 name  \
# 0           breast_cancer_classifier
# 1                   end2end-all-conv
# 2                          ICIAR2018
# 3      Breast-cancer-risk-prediction
# 4       breast-cancer-classification
# ..                               ...
# 95          Breast_Cancer_Prediction
# 96       Breast-Cancer-Detection-App
# 97  Breast-Cancer-Prediction-Project
# 98               BreastCancer-Kmeans
# 99          Breast-Cancer-Prediction
#
#                                             full_name  private  \
# 0                     nyukat/breast_cancer_classifier    False
# 1                             lishen/end2end-all-conv    False
# 2                                ImagingLab/ICIAR2018    False
# 3          Jean-njoroge/Breast-cancer-risk-prediction    False
# 4           abhinavsagar/breast-cancer-classification    False
# ..                                                ...      ...
# 95                BishalDali/Breast_Cancer_Prediction    False
# 96  IndianAIProduction-Channel/Breast-Cancer-Detec...    False
# 97            gmineo/Breast-Cancer-Prediction-Project    False
# 98                       iharnoor/BreastCancer-Kmeans    False
# 99            sagnikghoshcr7/Breast-Cancer-Prediction    False
#
#                                                 owner  \
# 0   {'login': 'nyukat', 'id': 38415695, 'node_id':...
# 1   {'login': 'lishen', 'id': 874315, 'node_id': '...
# 2   {'login': 'ImagingLab', 'id': 35308644, 'node_...
# 3   {'login': 'Jean-njoroge', 'id': 24501277, 'nod...
# 4   {'login': 'abhinavsagar', 'id': 40603139, 'nod...
# ..                                                ...
# 95  {'login': 'BishalDali', 'id': 84458919, 'node_...
# 96  {'login': 'IndianAIProduction-Channel', 'id': ...
# 97  {'login': 'gmineo', 'id': 39634149, 'node_id':...
# 98  {'login': 'iharnoor', 'id': 25940948, 'node_id...
# 99  {'login': 'sagnikghoshcr7', 'id': 58620359, 'n...
#
#                                              html_url  \
# 0   https://github.com/nyukat/breast_cancer_classi...
# 1          https://github.com/lishen/end2end-all-conv
# 2             https://github.com/ImagingLab/ICIAR2018
# 3   https://github.com/Jean-njoroge/Breast-cancer-...
# 4   https://github.com/abhinavsagar/breast-cancer-...
# ..                                                ...
# 95  https://github.com/BishalDali/Breast_Cancer_Pr...
# 96  https://github.com/IndianAIProduction-Channel/...
# 97  https://github.com/gmineo/Breast-Cancer-Predic...
# 98    https://github.com/iharnoor/BreastCancer-Kmeans
# 99  https://github.com/sagnikghoshcr7/Breast-Cance...
#
#                                           description   fork  \
# 0   Deep Neural Networks Improve Radiologists' Per...  False
# 1   Deep Learning to Improve Breast Cancer Detecti...  False
# 2   Two-Stage Convolutional Neural Network for Bre...  False
# 3   Classification of Breast Cancer diagnosis Usin...  False
# 4   Breast Cancer Classification using CNN and tra...  False
# ..                                                ...    ...
# 95                                               None  False
# 96  Breast Cancer Detection App Using Machine Lear...  False
# 97  Different approaches as (ANN,RandomForest,Baye...  False
# 98      Clustering the data into benign or malignant.  False
# 99  A machine learning process to distinguish good...  False
#
#                                                   url  ... is_template  \
# 0   https://api.github.com/repos/nyukat/breast_can...  ...       False
# 1   https://api.github.com/repos/lishen/end2end-al...  ...       False
# 2   https://api.github.com/repos/ImagingLab/ICIAR2018  ...       False
# 3   https://api.github.com/repos/Jean-njoroge/Brea...  ...       False
# 4   https://api.github.com/repos/abhinavsagar/brea...  ...       False
# ..                                                ...  ...         ...
# 95  https://api.github.com/repos/BishalDali/Breast...  ...       False
# 96  https://api.github.com/repos/IndianAIProductio...  ...       False
# 97  https://api.github.com/repos/gmineo/Breast-Can...  ...       False
# 98  https://api.github.com/repos/iharnoor/BreastCa...  ...       False
# 99  https://api.github.com/repos/sagnikghoshcr7/Br...  ...       False
#
#    web_commit_signoff_required  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ..                         ...
# 95                       False
# 96                       False
# 97                       False
# 98                       False
# 99                       False
#
#                                                topics visibility forks  \
# 0   [breast-cancer, breast-cancer-diagnosis, class...     public   254
# 1   [cancer-imaging-research, deep-learning, machi...     public   125
# 2   [breast-cancer, classification, deep-learning,...     public    74
# 3   [breast-cancer-prediction, breast-cancer-tumor...     public   123
# 4   [accuracy, benign-vs-malignant, breast-cancer-...     public    96
# ..                                                ...        ...   ...
# 95                                                 []     public     0
# 96                                                 []     public    26
# 97                                                 []     public     9
# 98  [kmeans-clustering, kmeansplusplus, knn-classi...     public     3
# 99       [breast-cancer-prediction, machine-learning]     public     4
#
#    open_issues watchers default_branch  \
# 0            1      795         master
# 1           16      334         master
# 2            8      197         master
# 3            3      186         master
# 4            7      178         master
# ..         ...      ...            ...
# 95           0       12           main
# 96           2       11         master
# 97           0       11         master
# 98           0       11         master
# 99           0       11         master
#
#                                           permissions score
# 0   {'admin': False, 'maintain': False, 'push': Fa...     1
# 1   {'admin': False, 'maintain': False, 'push': Fa...     1
# 2   {'admin': False, 'maintain': False, 'push': Fa...     1
# 3   {'admin': False, 'maintain': False, 'push': Fa...     1
# 4   {'admin': False, 'maintain': False, 'push': Fa...     1
# ..                                                ...   ...
# 95  {'admin': False, 'maintain': False, 'push': Fa...     1
# 96  {'admin': False, 'maintain': False, 'push': Fa...     1
# 97  {'admin': False, 'maintain': False, 'push': Fa...     1
# 98  {'admin': False, 'maintain': False, 'push': Fa...     1
# 99  {'admin': False, 'maintain': False, 'push': Fa...     1
#
# [100 rows x 81 columns]
