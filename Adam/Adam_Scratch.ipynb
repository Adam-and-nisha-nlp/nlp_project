# %%
# Goals: to find 800 repository and get ML to classify its language

# %% [markdown]
# # ACQUIRE

# %%
# import
import requests
import json
from bs4 import BeautifulSoup

# %%
# set up API request headers
from env import github_token, github_username

headers = {
    "Authorization": f"token {github_token}",
    "User-Agent": github_username
}
# Out:
# Traceback (most recent call last):
#
#   File /opt/homebrew/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 2
#     from env import github_token, github_username
#
#   File /opt/homebrew/anaconda3/lib/python3.10/site-packages/env.py:51
#     print k
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# make API requests to get repository names
language = "python"
api_url = f"https://api.github.com/search/repositories?q=language:{language}&sort=stars&order=desc&per_page=100"
response = requests.get(api_url, headers=headers)

if response.status_code == 200:
    repositories = response.json()["items"]
else:
    print(f"Failed to fetch repository list. Status code: {response.status_code}")
    exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 language = "python"
#       3 api_url = f"https://api.github.com/search/repositories?q=language:{language}&sort=stars&order=desc&per_page=100"
# ----> 4 response = requests.get(api_url, headers=headers)
#       6 if response.status_code == 200:
#       7     repositories = response.json()["items"]
#
# NameError: name 'headers' is not defined

# %%
url_to_call = "https://github.com/search?q=breast%20cancer&type=repositories"

# %%
breast_cancer_request = requests.get(url_to_call)

# %%
breast_cancer_request
# Out:
# <Response [200]>

# %%
breast_cancer_request.json()['payload']['results']
# Out:
# [{'id': '160983886',
#   'archived': False,
#   'color': '#DA5B0B',
#   'followers': 795,
#   'has_funding_file': False,
#   'hl_name': 'nyukat/<em>breast</em>_<em>cancer</em>_classifier',
#   'hl_trunc_description': "Deep Neural Networks Improve Radiologists' Performance in <em>Breast</em> <em>Cancer</em> Screening",
#   'language': 'Jupyter Notebook',
#   'mirror': False,
#   'owned_by_organization': True,
#   'public': True,
#   'repo': {'repository': {'id': 160983886,
#     'name': 'breast_cancer_classifier',
#     'owner_id': 38415695,
#     'owner_login': 'nyukat',
#     'updated_at': '2023-10-03T21:42:39.109Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': ['deep-learning',
#    'neural-network',
#    'tensorflow',
#    'pytorch',
#    'medical-imaging',
#    'classification',
#    'pretrained-models',
#    'breast-cancer',
#    'medical-image-analysis',
#    'breast-cancer-diagnosis'],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False},
#  {'id': '243785498',
#   'archived': False,
#   'color': '#3572A5',
#   'followers': 136,
#   'has_funding_file': False,
#   'hl_name': 'srimani-programmer/<em>Breast</em>-<em>Cancer</em>-Predictor',
#   'hl_trunc_description': 'A Flask based web application to predict <em>breast</em> <em>cancer</em>. ',
#   'language': 'Python',
#   'mirror': False,
#   'owned_by_organization': False,
#   'public': True,
#   'repo': {'repository': {'id': 243785498,
#     'name': 'Breast-Cancer-Predictor',
#     'owner_id': 42272691,
#     'owner_login': 'srimani-programmer',
#     'updated_at': '2023-05-13T07:12:41.871Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': [],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 6,
#   'starred_by_current_user': False},
#  {'id': '205845429',
#   'archived': False,
#   'color': '#DA5B0B',
#   'followers': 178,
#   'has_funding_file': False,
#   'hl_name': 'abhinavsagar/<em>breast</em>-<em>cancer</em>-classification',
#   'hl_trunc_description': '<em>Breast</em> <em>Cancer</em> Classification using CNN and transfer learning',
#   'language': 'Jupyter Notebook',
#   'mirror': False,
#   'owned_by_organization': False,
#   'public': True,
#   'repo': {'repository': {'id': 205845429,
#     'name': 'breast-cancer-classification',
#     'owner_id': 40603139,
#     'owner_login': 'abhinavsagar',
#     'updated_at': '2021-06-07T13:02:40.088Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': ['convolutional-neural-networks',
#    'deep-learning',
#    'deep-neural-networks',
#    'neural-network',
#    'accuracy',
#    'cnn-classification',
#    'roc-auc',
#    'breast-cancer-classification',
#    'benign-vs-malignant'],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False},
#  {'id': '76322499',
#   'archived': False,
#   'color': '#DA5B0B',
#   'followers': 186,
#   'has_funding_file': False,
#   'hl_name': 'Jean-njoroge/<em>Breast</em>-<em>cancer</em>-risk-prediction',
#   'hl_trunc_description': 'Classification of <em>Breast</em> <em>Cancer</em> diagnosis Using Support Vector Machines',
#   'language': 'Jupyter Notebook',
#   'mirror': False,
#   'owned_by_organization': False,
#   'public': True,
#   'repo': {'repository': {'id': 76322499,
#     'name': 'Breast-cancer-risk-prediction',
#     'owner_id': 24501277,
#     'owner_login': 'Jean-njoroge',
#     'updated_at': '2022-10-15T16:02:31.125Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': ['python',
#    'notebook',
#    'svm',
#    'exploratory-data-analysis',
#    'pipelines',
#    'supervised-learning',
#    'classification',
#    'data-analysis',
#    'breast-cancer-prediction',
#    'prediction-model',
#    'dataprocessing',
#    'breast-cancer-tumor',
#    'breastcancer-classification'],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False},
#  {'id': '108012253',
#   'archived': False,
#   'color': '#3572A5',
#   'followers': 62,
#   'has_funding_file': False,
#   'hl_name': 'akshaybahadur21/<em>BreastCancer</em>_Classification',
#   'hl_trunc_description': 'Machine learning classifier for <em>cancer</em> tissues 🔬',
#   'language': 'Python',
#   'mirror': False,
#   'owned_by_organization': False,
#   'public': True,
#   'repo': {'repository': {'id': 108012253,
#     'name': 'BreastCancer_Classification',
#     'owner_id': 22640610,
#     'owner_login': 'akshaybahadur21',
#     'updated_at': '2021-06-04T09:21:20.747Z',
#     'has_issues': True}},
#   'sponsorable': True,
#   'topics': ['machine-learning',
#    'python',
#    'logistic-regression',
#    'breast-cancer-prediction',
#    'breast-cancer-wisconsin',
#    'breast-cancer',
#    'dataset-uci'],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False},
#  {'id': '116251901',
#   'archived': False,
#   'color': '#3572A5',
#   'followers': 19,
#   'has_funding_file': False,
#   'hl_name': 'datasets/<em>breast</em>-<em>cancer</em>',
#   'hl_trunc_description': '<em>Breast</em> <em>cancer</em> occurrences.',
#   'language': 'Python',
#   'mirror': False,
#   'owned_by_organization': True,
#   'public': True,
#   'repo': {'repository': {'id': 116251901,
#     'name': 'breast-cancer',
#     'owner_id': 1643515,
#     'owner_login': 'datasets',
#     'updated_at': '2018-02-20T08:36:52.248Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': [],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False},
#  {'id': '100740147',
#   'archived': False,
#   'color': '#DA5B0B',
#   'followers': 334,
#   'has_funding_file': False,
#   'hl_name': 'lishen/end2end-all-conv',
#   'hl_trunc_description': 'Deep Learning to Improve <em>Breast</em> <em>Cancer</em> Detection on Screening Mammography',
#   'language': 'Jupyter Notebook',
#   'mirror': False,
#   'owned_by_organization': False,
#   'public': True,
#   'repo': {'repository': {'id': 100740147,
#     'name': 'end2end-all-conv',
#     'owner_id': 874315,
#     'owner_login': 'lishen',
#     'updated_at': '2022-02-24T19:00:58.686Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': ['machine-learning', 'deep-learning', 'cancer-imaging-research'],
#   'type': 'Public',
#   'help_wanted_issues_count': 1,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False},
#  {'id': '166364571',
#   'archived': False,
#   'color': '#3572A5',
#   'followers': 44,
#   'has_funding_file': False,
#   'hl_name': 'cystanford/<em>breast</em>_<em>cancer</em>_data',
#   'hl_trunc_description': '乳腺癌检测分类数据',
#   'language': 'Python',
#   'mirror': False,
#   'owned_by_organization': False,
#   'public': True,
#   'repo': {'repository': {'id': 166364571,
#     'name': 'breast_cancer_data',
#     'owner_id': 35882376,
#     'owner_login': 'cystanford',
#     'updated_at': '2023-09-18T00:17:11.237Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': [],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False},
#  {'id': '116997617',
#   'archived': False,
#   'color': '#3572A5',
#   'followers': 197,
#   'has_funding_file': False,
#   'hl_name': 'ImagingLab/ICIAR2018',
#   'hl_trunc_description': 'Two-Stage Convolutional Neural Network for <em>Breast</em> <em>Cancer</em> Histology Image Classification. ICIAR 2018 Grand Challenge on <em>BreAst</em> <em>Cancer</em> Hist…',
#   'language': 'Python',
#   'mirror': False,
#   'owned_by_organization': True,
#   'public': True,
#   'repo': {'repository': {'id': 116997617,
#     'name': 'ICIAR2018',
#     'owner_id': 35308644,
#     'owner_login': 'ImagingLab',
#     'updated_at': '2019-10-23T15:27:19.403Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': ['pytorch',
#    'deep-learning',
#    'image-classification',
#    'medical-imaging',
#    'classification',
#    'histology',
#    'breast-cancer'],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False},
#  {'id': '167238507',
#   'archived': False,
#   'color': '#DA5B0B',
#   'followers': 41,
#   'has_funding_file': False,
#   'hl_name': 'gscdit/<em>Breast</em>-<em>Cancer</em>-Detection',
#   'hl_trunc_description': '<em>Breast</em> <em>Cancer</em> Detection Using Machine Learning',
#   'language': 'Jupyter Notebook',
#   'mirror': False,
#   'owned_by_organization': True,
#   'public': True,
#   'repo': {'repository': {'id': 167238507,
#     'name': 'Breast-Cancer-Detection',
#     'owner_id': 25609718,
#     'owner_login': 'gscdit',
#     'updated_at': '2019-01-27T16:16:26.498Z',
#     'has_issues': True}},
#   'sponsorable': False,
#   'topics': ['svm',
#    'ml',
#    'svm-classifier',
#    'normalization',
#    'cancer-detection'],
#   'type': 'Public',
#   'help_wanted_issues_count': 0,
#   'good_first_issue_issues_count': 0,
#   'starred_by_current_user': False}]

# %% [markdown]
# Goal: add all these results to a list, then find a way to go through and request another 10 results with always adding them to a list. clean up emphasis text from entries

# %%
def get_repository_details(repo_full_name):
    repo_url = f"https://api.github.com/repos/{repo_full_name}"
    readme_url = f"https://api.github.com/repos/{repo_full_name}/readme"
    repo_response = requests.get(repo_url, headers=headers)
    readme_response = requests.get(readme_url, headers=headers)
    if repo_response.status_code == 200 and readme_response.status_code == 200:
        repo_data = repo_response.json()
        readme_data = readme_response.json()
        language = repo_data["language"]
        readme_contents = requests.get(readme_data["download_url"]).text
        return {
            "repo": "/" + repo_full_name,
            "language": language,
            "readme_contents": readme_contents
        }
    else:
        return None

# %%
# Your GitHub API token and username
from env import github_token, github_username

# Define the headers with your token and username
headers = {
    "Authorization": f"token {github_token}",
    "User-Agent": github_username
}

# Define a function to get repositories based on a query and page
def get_repositories(query, sort="stars", order="desc", page=1):
    base_url = "https://api.github.com/search/repositories"
    params = {
        "q": query,
        "sort": sort,
        "order": order,
        "per_page": 10,  # You can get up to 100 results per page.
        "page": page  # Specify the page number
    }
    response = requests.get(base_url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# Search for breast cancer related repositories and handle pagination
query = "breast cancer"
page = 1

while page <=10:
    response_json = get_repositories(query, page=page)
    if response_json is None:
        print(f"Failed to fetch page {page} of repositories.")
        break

    # Extract and print repository names
    for repo in response_json["items"]:
        print(repo["full_name"])

    # Check if there are more pages
    if "Link" in response.headers:
        next_link = response.headers["Link"]
        if 'rel="next"' not in next_link:
            break
    else:
        break
    page += 1
# Out:
# Traceback (most recent call last):
#
#   File /opt/homebrew/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 2
#     from env import github_token, github_username
#
#   File /opt/homebrew/anaconda3/lib/python3.10/site-packages/env.py:51
#     print k
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# Save data to JSON file 
with open("breast_cancer_repositories.json", "w") as json_file:
    json.dump(repos, json_file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Save data to JSON file
#       2 with open("breast_cancer_repositories.json", "w") as json_file:
# ----> 3     json.dump(repos, json_file, indent=4)
#
# NameError: name 'repos' is not defined
